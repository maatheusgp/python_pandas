# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/st1paulama/Desktop/votacao_partido_munzona_2020_BRASIL.csv",
                 error_bad_lines=False,
                 sep=';',
                encoding='ISO-8859-1')
df
# Out:
#        DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 0      05/10/2021   09:23:44         2020                2  Eleição Ordinária
# 1      05/10/2021   09:23:44         2020                2  Eleição Ordinária
# 2      05/10/2021   09:23:44         2020                2  Eleição Ordinária
# 3      05/10/2021   09:23:44         2020                2  Eleição Ordinária
# 4      05/10/2021   09:23:44         2020                2  Eleição Ordinária
# ...           ...        ...          ...              ...                ...
# 77184  05/10/2021   09:23:44         2020                2  Eleição Ordinária
# 77185  05/10/2021   09:23:44         2020                2  Eleição Ordinária
# 77186  05/10/2021   09:23:44         2020                2  Eleição Ordinária
# 77187  05/10/2021   09:23:44         2020                2  Eleição Ordinária
# 77188  05/10/2021   09:23:44         2020                2  Eleição Ordinária
#
# ...

# %%
df.groupby('SG_UF').sum()
# Out:
#        ANO_ELEICAO  CD_TIPO_ELEICAO  NR_TURNO  CD_ELEICAO      SG_UE  \
# SG_UF
# AC          721140              714       361      152086     442159
# AL         2088680             2065      1044      440728   28843048
# AM         1811940             1794       923      382148   15271730
# AP          626200              620       314      133432    1885042
# BA        10524200            10418      5224     2219678  190653558
# CE         4981320             4926      2506     1050908   36925492
# ES         2991620             2959      1501      631121   83879947
# GO         6395320             6332      3190     1348740  297498130
# MA         5078280             5028      2526     1070976   20817181
# MG        21070620            20848     10459     4444453  482592532
# MS         2310880             2283      1144      487714  102574772
# MT         3409760             3369      1696      719531  155198877
# ...

# %%
df.groupby(['SG_UF', 'SG_PARTIDO', 'DS_CARGO']).sum().head(50)
# Out:
#                               ANO_ELEICAO  CD_TIPO_ELEICAO  NR_TURNO  \
# SG_UF SG_PARTIDO    DS_CARGO
# AC    AVANTE        Prefeito         4040                4         2
#                     Vereador         6060                6         3
#       CIDADANIA     Vereador         4040                4         2
#       DC            Vereador        10100               10         5
#       DEM           Prefeito         4040                4         2
#                     Vereador        32320               32        16
#       MDB           Prefeito        38380               38        19
#                     Vereador        46460               46        23
#       PATRIOTA      Vereador         6060                6         3
#       PC do B       Prefeito         6060                6         3
#                     Vereador        30300               30        15
#       PCB           Vereador         4040                4         2
# ...

# %%
df.groupby(['SG_UF', 'SG_PARTIDO', 'DS_CARGO']).sum().head(50).reset_index()
# Out:
#    SG_UF     SG_PARTIDO  DS_CARGO  ANO_ELEICAO  CD_TIPO_ELEICAO  NR_TURNO  \
# 0     AC         AVANTE  Prefeito         4040                4         2
# 1     AC         AVANTE  Vereador         6060                6         3
# 2     AC      CIDADANIA  Vereador         4040                4         2
# 3     AC             DC  Vereador        10100               10         5
# 4     AC            DEM  Prefeito         4040                4         2
# 5     AC            DEM  Vereador        32320               32        16
# 6     AC            MDB  Prefeito        38380               38        19
# 7     AC            MDB  Vereador        46460               46        23
# 8     AC       PATRIOTA  Vereador         6060                6         3
# 9     AC        PC do B  Prefeito         6060                6         3
# 10    AC        PC do B  Vereador        30300               30        15
# 11    AC            PCB  Vereador         4040                4         2
# ...

# %%
df.groupby(['SG_UF', 'SG_PARTIDO', 'DS_CARGO', 'NR_TURNO'], as_index=False).sum().head(50)
# Out:
#    SG_UF     SG_PARTIDO  DS_CARGO  NR_TURNO  ANO_ELEICAO  CD_TIPO_ELEICAO  \
# 0     AC         AVANTE  Prefeito         1         4040                4
# 1     AC         AVANTE  Vereador         1         6060                6
# 2     AC      CIDADANIA  Vereador         1         4040                4
# 3     AC             DC  Vereador         1        10100               10
# 4     AC            DEM  Prefeito         1         4040                4
# 5     AC            DEM  Vereador         1        32320               32
# 6     AC            MDB  Prefeito         1        38380               38
# 7     AC            MDB  Vereador         1        46460               46
# 8     AC       PATRIOTA  Vereador         1         6060                6
# 9     AC        PC do B  Prefeito         1         6060                6
# 10    AC        PC do B  Vereador         1        30300               30
# 11    AC            PCB  Vereador         1         4040                4
# ...

# %%
#USANDO A FUNÇÃO AGG
df.groupby('SG_UF').agg({'QT_VOTOS_NOMINAIS': 'sum', 'QT_VOTOS_LEGENDA':'mean'})
# Out:
#        QT_VOTOS_NOMINAIS  QT_VOTOS_LEGENDA
# SG_UF
# AC                960763         68.333333
# AL               3498740         86.945841
# AM               2555148         44.333333
# AP                895238         44.696774
# BA              15915555         98.419578
# CE              11263478        113.427007
# ES               4535125         66.107360
# GO               7011234         53.052116
# MA               7647783         74.683373
# MG              22255314         61.303135
# MS               2553755         63.311189
# MT               3410694         41.573460
# PA               9302732         80.873132
# PB               4811330         61.081453
# PE              10544812         97.914589
# PI               4202026         57.349151
# PR              11132727         61.440048
# RJ              17854631         77.126723
# RN               3558759         53.508911
# RO               1743380         49.179012
# RR                644120         35.659919
# ...

# %%
df.groupby('SG_UF').size()
# Out:
# SG_UF
# AC      357
# AL     1034
# AM      897
# AP      310
# BA     5210
# CE     2466
# ES     1481
# GO     3166
# MA     2514
# MG    10431
# MS     1144
# MT     1688
# PA     2743
# PB     1817
# PE     2728
# PI     1707
# PR     4979
# RJ     5587
# RN     1515
# RO      810
# RR      247
# RS     5154
# SC     3355
# SE      794
# SP    13801
# TO     1254
# dtype: int64

# %%
df.groupby('SG_UF').size().reset_index()
# Out:
#    SG_UF      0
# 0     AC    357
# 1     AL   1034
# 2     AM    897
# 3     AP    310
# 4     BA   5210
# 5     CE   2466
# 6     ES   1481
# 7     GO   3166
# 8     MA   2514
# 9     MG  10431
# 10    MS   1144
# 11    MT   1688
# 12    PA   2743
# 13    PB   1817
# 14    PE   2728
# 15    PI   1707
# 16    PR   4979
# 17    RJ   5587
# 18    RN   1515
# 19    RO    810
# 20    RR    247
# 21    RS   5154
# 22    SC   3355
# 23    SE    794
# 24    SP  13801
# 25    TO   1254

# %%
len(df[df['SG_UF'] == 'SP'])
# Out:
# 13801
