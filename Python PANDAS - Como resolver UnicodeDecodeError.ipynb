# %%
import pandas as pd

# %%
a = pd.read_csv('http://repositorio.dados.gov.br/sest/OI-Receita.csv', encoding='ISO-8859-1', sep=';')
a.head()
# Out:
#   Exercício Grupo Cód.                   Grupo Cód. Empresa Sigla Empresa  \
# 0     Total      Total                   Total        Total         Total
# 1      2019         40  DEMAIS EMPRESAS DO SPE        22208    Ceasaminas
# 2      2019         40  DEMAIS EMPRESAS DO SPE        22209        Casemg
# 3      2019         40  DEMAIS EMPRESAS DO SPE        22212       Ceagesp
# 4      2019         40  DEMAIS EMPRESAS DO SPE        24214           ECT
#
#   Fonte Mãe Código          Fonte Mãe Fonte Cód.            Fonte  \
# 0            Total              Total      Total            Total
# 1         61000000  Recursos Próprios   61100000  Geração Própria
# 2         61000000  Recursos Próprios   61100000  Geração Própria
# 3         61000000  Recursos Próprios   61100000  Geração Própria
# 4         61000000  Recursos Próprios   61100000  Geração Própria
#
#               PLoa  ... Realizado até Mar Realizado até Abr Realizado até Mai  \
# ...
