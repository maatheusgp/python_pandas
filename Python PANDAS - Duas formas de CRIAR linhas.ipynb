# %%
import pandas as pd

# %%
dados = [['1A', '2A'], ['1B', '2B'], ['1C', '2C'],
         ['1D', '2D'], ['1E', '2E'], ['1F', '2F']]
df1 = pd.DataFrame (dados, columns=['col1', 'col2'])
df1
# Out:
#   col1 col2
# 0   1A   2A
# 1   1B   2B
# 2   1C   2C
# 3   1D   2D
# 4   1E   2E
# 5   1F   2F

# %%
#Passar o parâmetro ignore_index=True é obrigatório
df1.append({'col1':'1G', 'col2':'2F'}, ignore_index=True)
# Out:
#   col1 col2
# 0   1A   2A
# 1   1B   2B
# 2   1C   2C
# 3   1D   2D
# 4   1E   2E
# 5   1F   2F
# 6   1G   2F

# %%
df1 = df1.append({'col1':'1G', 'col2':'2F'}, ignore_index=True)

# %%
df1
# Out:
#   col1 col2
# 0   1A   2A
# 1   1B   2B
# 2   1C   2C
# 3   1D   2D
# 4   1E   2E
# 5   1F   2F
# 6   1G   2F

# %%
#Outra forma de criar linha

# %%
#Essa função é inplace
df1.loc['OI'] = ['1G', '2G']

# %%
df1
# Out:
#    col1 col2
# 0    1A   2A
# 1    1B   2B
# 2    1C   2C
# 3    1D   2D
# 4    1E   2E
# 5    1F   2F
# 6    1G   2F
# oi   1G   2G
# OI   1G   2G

# %%
df1.loc[len(df1)] = ['1G', '2G']

# %%
df1
# Out:
#    col1 col2
# 0    1A   2A
# 1    1B   2B
# 2    1C   2C
# 3    1D   2D
# 4    1E   2E
# 5    1F   2F
# 6    1G   2F
# oi   1G   2G
# OI   1G   2G
# 9    1G   2G
# 10   1G   2G

# %%
df1
# Out:
#    col1 col2
# 0    1A   2A
# 1    1B   2B
# 2    1C   2C
# 3    1D   2D
# 4    1E   2E
# 5    1F   2F
# 6    1G   2F
# oi   1G   2G
# OI   1G   2G
# 9    1G   2G
# 10   1G   2G
# 11   1G   2G
