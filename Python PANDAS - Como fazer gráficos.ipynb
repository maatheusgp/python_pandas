# %%
import pandas as pd
import numpy as np

# %%
dados = [[11.840, 37.570, 21.480, 10.280, 5.770],
         [16.430, 43.70, 18.810, 8.640],
         [14.440, 32.620, 17.110, 8.020, 6.950],
         [7.690, 33.330, 25.640, 10.260, 10.260],
         [7.890, 39.470, 13.160, 10.530, 10.530]]
df = pd.DataFrame(dados,
                 index=['Man', 'Woman', 'Prefer not to say', 'Prefer to self-describe', 'Nonbinary'],
                 columns=['Under 1 year', '1-2 years', '2-3 years', '3-4 years', '5-10 years'])
df
# Out:
#                          Under 1 year  1-2 years  2-3 years  3-4 years  \
# Man                             11.84      37.57      21.48      10.28
# Woman                           16.43      43.70      18.81       8.64
# Prefer not to say               14.44      32.62      17.11       8.02
# Prefer to self-describe          7.69      33.33      25.64      10.26
# Nonbinary                        7.89      39.47      13.16      10.53
#
#                          5-10 years
# Man                            5.77
# Woman                           NaN
# Prefer not to say              6.95
# Prefer to self-describe       10.26
# Nonbinary                     10.53

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df.plot(y='Under 1 year', kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='bar', subplots=True, layout=(5, 5), figsize=(20, 20))
# Out:
# array([[<AxesSubplot:title={'center':'Under 1 year'}>,
#         <AxesSubplot:title={'center':'1-2 years'}>,
#         <AxesSubplot:title={'center':'2-3 years'}>,
#         <AxesSubplot:title={'center':'3-4 years'}>,
#         <AxesSubplot:title={'center':'5-10 years'}>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#         <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#         <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#         <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
df.plot(kind='bar', subplots=True, layout=(3, 3), figsize=(20,20), sharey=True)
# Out:
# array([[<AxesSubplot:title={'center':'Under 1 year'}>,
#         <AxesSubplot:title={'center':'1-2 years'}>,
#         <AxesSubplot:title={'center':'2-3 years'}>],
#        [<AxesSubplot:title={'center':'3-4 years'}>,
#         <AxesSubplot:title={'center':'5-10 years'}>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
df.plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='bar', stacked=True, rot=0)
# Out:
# <AxesSubplot:>
