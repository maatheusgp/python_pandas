# %%
import pandas as pd
import numpy as np

# %%
dados = np.random.rand(150, 14)
df = pd.DataFrame(dados * 1000, columns=['col1', 'col2', 'col3', 'col4', 'col5', 'col6', 'col7', 'col9', 'col10', 'col11', 'col12','col13','col14','col15'])
df
# Out:
#            col1        col2        col3        col4        col5        col6  \
# 0    871.160814  416.489879  778.625517  686.620242  831.498068   44.330840
# 1    776.913624  896.074875  534.119742   38.138428  122.784503  112.574037
# 2     69.037128   89.281753  421.517433  782.503980  461.279220  757.200016
# 3    622.920938  914.480664  695.208492  918.481566  579.321311  751.207628
# 4    490.241222  110.619850  148.041482  161.881284  665.435710  793.455928
# ..          ...         ...         ...         ...         ...         ...
# 145  886.033979  662.294415  342.564341   56.258112  445.951099  261.285049
# 146  419.507230  973.714851   35.391573  653.996627  971.824509  547.944591
# 147  323.431900  170.362839  894.907806  320.125673   76.957813  165.236817
# 148  960.952948  151.999424   39.173723  575.413702  575.954945  699.450052
# 149  916.977399  329.042484  810.143047  208.981002  387.503717  891.009827
#
# ...

# %%
#Mostra todas as colunas do DF
pd.set_option('display.max_rows', None)

# %%
#Mostra todas as linhas do DF
pd.set_option('display.max_rows', None)

# %%
#Limita o valor de cada digito
pd.set_option('display.max_colwidht', 10)
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# <ipython-input-52-b020bb685336> in <module>
#       1 #Limita o valor de cada digito
# ----> 2 pd.set_option('display.max_colwidht', 10)
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\_config\config.py in __call__(self, *args, **kwds)
#     231
#     232     def __call__(self, *args, **kwds):
# --> 233         return self.__func__(*args, **kwds)
#     234
#     235     @property
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\_config\config.py in _set_option(*args, **kwargs)
#     124
#     125     for k, v in zip(args[::2], args[1::2]):
# --> 126         key = _get_single_key(k, silent)
#     127
#     128         o = _get_registered_option(key)
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\_config\config.py in _get_single_key(pat, silent)
#      89         if not silent:
# ...

# %%
#Retorna o Df ao original
pd.reset_option('^display', silent=True)
df
# Out:
#            col1        col2        col3        col4        col5        col6  \
# 0    797.839710  460.852496   72.666343  754.824139  336.698574  969.855559
# 1    517.743394  580.613559  836.178332  987.215065  159.114542  607.967736
# 2    372.743399  670.993522  198.851763   33.987082  363.256427  411.474063
# 3    923.575857  197.889714  794.087561  735.097253  337.902579   19.836384
# 4    352.645132  101.796603  784.230467  622.206477  544.474467  584.540855
# ..          ...         ...         ...         ...         ...         ...
# 145  793.291748  517.598506   71.832749  999.236568  979.018928  634.850474
# 146  899.344845  853.025817  143.897059  737.518122    9.829747  749.114720
# 147  504.398770  901.788110  577.143317  388.103496  468.571908   38.797871
# 148  832.875031  189.303256  885.199335  190.466432    9.859720  143.857983
# 149  182.120497  570.304921  843.039529  867.739360  823.799690  973.733302
#
# ...
